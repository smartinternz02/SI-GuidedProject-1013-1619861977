# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\JahnaviP\Downloads\petrol_consumption.csv")

# %%
data.isnull().any()
# Out:
# Petrol_tax                      False
# Average_income                  False
# Paved_Highways                  False
# Population_Driver_licence(%)    False
# Petrol_Consumption              False
# dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
# Petrol_tax                      48 non-null float64
# Average_income                  48 non-null int64
# Paved_Highways                  48 non-null int64
# Population_Driver_licence(%)    48 non-null float64
# Petrol_Consumption              48 non-null int64
# dtypes: float64(2), int64(3)
# memory usage: 2.0 KB

# %%
data
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
x=data.iloc[:,0:4].values
y=data.iloc[:,4].values

# %%
data.head(1)
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
#
#    Petrol_Consumption
# 0                 541

# %%
x
# Out:
# array([[9.0000e+00, 3.5710e+03, 1.9760e+03, 5.2500e-01],
#        [9.0000e+00, 4.0920e+03, 1.2500e+03, 5.7200e-01],
#        [9.0000e+00, 3.8650e+03, 1.5860e+03, 5.8000e-01],
#        [7.5000e+00, 4.8700e+03, 2.3510e+03, 5.2900e-01],
#        [8.0000e+00, 4.3990e+03, 4.3100e+02, 5.4400e-01],
#        [1.0000e+01, 5.3420e+03, 1.3330e+03, 5.7100e-01],
#        [8.0000e+00, 5.3190e+03, 1.1868e+04, 4.5100e-01],
#        [8.0000e+00, 5.1260e+03, 2.1380e+03, 5.5300e-01],
#        [8.0000e+00, 4.4470e+03, 8.5770e+03, 5.2900e-01],
#        [7.0000e+00, 4.5120e+03, 8.5070e+03, 5.5200e-01],
#        [8.0000e+00, 4.3910e+03, 5.9390e+03, 5.3000e-01],
#        [7.5000e+00, 5.1260e+03, 1.4186e+04, 5.2500e-01],
#        [7.0000e+00, 4.8170e+03, 6.9300e+03, 5.7400e-01],
#        [7.0000e+00, 4.2070e+03, 6.5800e+03, 5.4500e-01],
#        [7.0000e+00, 4.3320e+03, 8.1590e+03, 6.0800e-01],
#        [7.0000e+00, 4.3180e+03, 1.0340e+04, 5.8600e-01],
# ...

# %%
y
# Out:
# array([541, 524, 561, 414, 410, 457, 344, 467, 464, 498, 580, 471, 525,
#        508, 566, 635, 603, 714, 865, 640, 649, 540, 464, 547, 460, 566,
#        577, 631, 574, 534, 571, 554, 577, 628, 487, 644, 640, 704, 648,
#        968, 587, 699, 632, 591, 782, 510, 610, 524], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
x_test
# Out:
# array([[8.0000e+00, 5.3190e+03, 1.1868e+04, 4.5100e-01],
#        [8.0000e+00, 4.1880e+03, 5.9750e+03, 5.6300e-01],
#        [8.0000e+00, 3.0630e+03, 6.5240e+03, 5.7800e-01],
#        [8.0000e+00, 3.4480e+03, 5.3990e+03, 5.4800e-01],
#        [7.0000e+00, 3.6560e+03, 3.9850e+03, 5.6300e-01],
#        [7.0000e+00, 5.0020e+03, 9.7940e+03, 5.9300e-01],
#        [1.0000e+01, 5.3420e+03, 1.3330e+03, 5.7100e-01],
#        [7.0000e+00, 4.4490e+03, 4.6390e+03, 6.2600e-01],
#        [7.0000e+00, 4.7160e+03, 5.9150e+03, 7.2400e-01],
#        [7.0000e+00, 3.3330e+03, 6.5940e+03, 5.1300e-01]])

# %%
y_test
# Out:
# array([344, 574, 577, 577, 699, 524, 457, 587, 865, 554], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
dtpred=dt.predict(x_test)

# %%
dtpred
# Out:
# array([471., 580., 580., 580., 628., 525., 510., 525., 968., 571.])

# %%
y_test
# Out:
# array([344, 574, 577, 577, 699, 524, 457, 587, 865, 554], dtype=int64)

# %%
from sklearn.metrics import r2_score,confusion_matrix
accuracy=r2_score(y_test,dtpred)
confmat=confusion_matrix(y_test,dtpred)

# %%
accuracy
# Out:
# 0.7718382391014748

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=40)
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=40,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rfpred=rf.predict(x_test)

# %%
rfpred
# Out:
# array([472.15 , 576.025, 610.525, 582.9  , 609.75 , 560.3  , 504.2  ,
#        599.575, 765.125, 573.625])

# %%
y_test
# Out:
# array([344, 574, 577, 577, 699, 524, 457, 587, 865, 554], dtype=int64)

# %%
from sklearn.metrics import r2_score
accuracy=r2_score(rfpred,y_test)

# %%
accuracy
# Out:
# 0.266504189256489

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
mlrp=mlr.predict(x_test)

# %%
mlrp
# Out:
# array([310.72647078, 558.70532501, 666.96404634, 600.10738362,
#        642.97098064, 560.32488051, 412.83775821, 658.79239232,
#        760.34665877, 598.72586847])

# %%
y_test
# Out:
# array([344, 574, 577, 577, 699, 524, 457, 587, 865, 554], dtype=int64)

# %%
from sklearn.metrics import r2_score
acc=r2_score(rfpred,y_test)

# %%
acc
# Out:
# 0.266504189256489

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
petrol=Sequential()

# %%
x.shape
# Out:
# (48, 4)

# %%
petrol.add(Dense(4,kernel_initializer="random_uniform",activation="relu"))

# %%
petrol.add(Dense(8,kernel_initializer="random_uniform",activation="relu"))

# %%
petrol.add(Dense(1,kernel_initializer="random_uniform",activation="relu"))

# %%
petrol.compile("adam",loss="mean_squared_error")

# %%
petrol.fit(x_train,y_train,batch_size=10,epochs=10000)
# Out:
# Epoch 1/10000
# 4/4 [==============================] - 0s 4ms/step - loss: 3424.3582
# Epoch 2/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 3422.9563
# Epoch 3/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 3419.7527
# Epoch 4/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 3418.8376
# Epoch 5/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 3416.1855
# Epoch 6/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 3415.9771
# Epoch 7/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 3415.7983
# Epoch 8/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 3411.2456
# Epoch 9/10000
# 4/4 [==============================] - 0s 1ms/step - loss: 3409.5693
# Epoch 10/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 3409.0762
# Epoch 11/10000
# 4/4 [==============================] - 0s 2ms/step - loss: 3406.7642
# Epoch 12/10000
# ...

# %%
ypred=petrol.predict(x_test)

# %%
ypred
# Out:
# array([[684.33777],
#        [547.49713],
#        [696.3339 ],
#        [616.6694 ],
#        [638.66876],
#        [517.65454],
#        [490.77002],
#        [618.1379 ],
#        [929.48615],
#        [620.26764]], dtype=float32)

# %%
y_test
# Out:
# array([344, 574, 577, 577, 699, 524, 457, 587, 865, 554], dtype=int64)

# %%
a=petrol.predict(sc.transform([[9,3571,1976,0.525]]))

# %%
data.head(1)
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
#
#    Petrol_Consumption
# 0                 541

# %%
a
# Out:
# array([[545.11115]], dtype=float32)
